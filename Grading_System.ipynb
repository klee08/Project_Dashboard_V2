# %%
import requests
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import pandas as pd
from itertools import cycle
from csv import reader
from pathlib import Path
import seaborn as sns
import numpy as np
import statistics
import ast
import sys
import time
import os
import csv

# %%
avg_sector_metrics_df = pd.read_csv(
    Path("Resources/AverageSectorMetrics.csv")
)

avg_sector_metrics_df.columns=['metrics', 'basicmaterials', ' communicationservices', ' consumercyclical',
       ' consumerdefensive', ' energy', ' financial', ' healthcare',
       ' industrials', ' realestate', ' technology', ' utilities']

avg_sector_metrics_df
# Out:
#              metrics  basicmaterials   communicationservices  \
# 0         Forward PE          11.880                  12.680
# 1                PEG           1.950                   2.315
# 2        Price/Sales           0.760                   1.070
# 3         Price/Book           1.220                   1.330
# 4          Price/FCF          11.940                  14.630
# 5         EPS This Y          -4.400                  -0.900
# 6         EPS Next Y          32.800                  31.580
# 7        EPS Next 5Y           8.000                   7.850
# 8            EPS Q/Q          -3.800                  -2.400
# 9          Sales Q/Q          -3.000                   1.000
# 10               ROA           2.650                   1.100
# 11               ROE           5.100                   2.800
# 12               ROI           6.800                   4.000
# 13     Current Ratio           2.000                   1.400
# ...

# %%
avg_sector_metrics_df.set_index("metrics", inplace=True, drop=True)

# %%
avg_sector_metrics_df.head()
# Out:
#              basicmaterials   communicationservices   consumercyclical  \
# metrics
# Forward PE            11.88                  12.680              12.41
# PEG                    1.95                   2.315               1.52
# Price/Sales            0.76                   1.070               0.51
# Price/Book             1.22                   1.330               1.15
# Price/FCF             11.94                  14.630              10.63
#
#               consumerdefensive   energy   financial   healthcare  \
# metrics
# Forward PE               15.470     9.30       8.690       18.390
# PEG                       2.735     0.83       1.060        3.255
# Price/Sales               0.880     0.43       2.305        5.760
# Price/Book                1.620     0.60       0.780        3.220
# Price/FCF                16.710     3.48       8.970       26.175
#
#               industrials   realestate   technology   utilities
# metrics
# ...

# %%
val_stats_df = avg_sector_metrics_df.loc[["Forward PE" , "PEG", "Price/Sales", "Price/Book", "Price/FCF"]]

# %%
val_stats_df.head()
# Out:
#              basicmaterials   communicationservices   consumercyclical  \
# metrics
# Forward PE            11.88                  12.680              12.41
# PEG                    1.95                   2.315               1.52
# Price/Sales            0.76                   1.070               0.51
# Price/Book             1.22                   1.330               1.15
# Price/FCF             11.94                  14.630              10.63
#
#               consumerdefensive   energy   financial   healthcare  \
# metrics
# Forward PE               15.470     9.30       8.690       18.390
# PEG                       2.735     0.83       1.060        3.255
# Price/Sales               0.880     0.43       2.305        5.760
# Price/Book                1.620     0.60       0.780        3.220
# Price/FCF                16.710     3.48       8.970       26.175
#
#               industrials   realestate   technology   utilities
# metrics
# ...

# %%
growth_stats_df = avg_sector_metrics_df.loc[["EPS This Y", "EPS Next Y", "EPS Next 5Y", "Sales Q/Q", "EPS Q/Q"]]

# %%
growth_stats_df
# Out:
#              basicmaterials   communicationservices   consumercyclical  \
# metrics
# EPS This Y             -4.4                   -0.90                6.3
# EPS Next Y             32.8                   31.58               50.0
# EPS Next 5Y             8.0                    7.85                9.3
# Sales Q/Q              -3.0                    1.00                1.0
# EPS Q/Q                -3.8                   -2.40               -1.2
#
#               consumerdefensive   energy   financial   healthcare  \
# metrics
# EPS This Y                4.500  -11.800        7.90         9.75
# EPS Next Y               12.605   11.155        8.46        16.90
# EPS Next 5Y               7.450    5.050        8.00        12.17
# Sales Q/Q                 3.600   -8.200        0.90         5.40
# EPS Q/Q                  -1.500  -46.000        6.10        12.40
#
#               industrials   realestate   technology   utilities
# metrics
# ...

# %%
profit_stats_df = avg_sector_metrics_df.loc[["Net Margin", "Operating Margin", "Gross Margin", "ROE", "ROA"]]

# %%
profit_stats_df
# Out:
#                   basicmaterials   communicationservices   consumercyclical  \
# metrics
# Net Margin                  4.20                    2.05               3.70
# Operating Margin            7.75                    6.20               5.75
# Gross Margin               23.00                   55.10              32.80
# ROE                         5.10                    2.80               8.80
# ROA                         2.65                    1.10               3.70
#
#                    consumerdefensive   energy   financial   healthcare  \
# metrics
# Net Margin                       3.4     0.65       21.10          2.5
# Operating Margin                 5.4     5.45       62.50          5.0
# Gross Margin                    34.0    43.40       73.05         62.0
# ROE                              8.0     1.10        9.10        -39.9
# ROA                              3.7    -0.10        1.10        -30.0
#
# ...

# %%
perf_stats_df = avg_sector_metrics_df.loc[["Perf Month", "Perf Quarter", "Perf Half Y", "Perf Year", "Perf YTD", "Volatility Month"]]

# %%
perf_stats_df
# Out:
#                   basicmaterials   communicationservices   consumercyclical  \
# metrics
# Perf Month                 5.260                   1.170              3.820
# Perf Quarter             -28.300                 -27.905            -39.710
# Perf Half Y              -29.435                 -26.110            -39.170
# Perf Year                -30.835                 -31.980            -39.375
# Perf YTD                 -32.100                 -27.910            -39.780
# Volatility Month           5.990                   5.620              6.930
#
#                    consumerdefensive   energy   financial   healthcare  \
# metrics
# Perf Month                      0.70    8.805       0.690         5.38
# Perf Quarter                  -15.76  -46.120     -19.850       -15.85
# Perf Half Y                   -13.27  -52.310     -16.955        -5.98
# Perf Year                     -20.45  -64.140     -13.985       -21.23
# ...

# %%
daily_returns_perf_df = perf_stats_df.pct_change().dropna()

daily_returns_perf_df
# Out:
#                   basicmaterials   communicationservices   consumercyclical  \
# metrics
# Perf Quarter           -6.380228              -24.850427         -11.395288
# Perf Half Y             0.040106               -0.064325          -0.013599
# Perf Year               0.047562                0.224818           0.005234
# Perf YTD                0.041025               -0.127267           0.010286
# Volatility Month       -1.186604               -1.201362          -1.174208
#
#                    consumerdefensive    energy   financial   healthcare  \
# metrics
# Perf Quarter              -23.514286 -6.237933  -29.768116    -3.946097
# Perf Half Y                -0.157995  0.134215   -0.145844    -0.622713
# Perf Year                   0.541070  0.226152   -0.175170     2.550167
# Perf YTD                   -0.080685 -0.149517    0.315695    -0.337730
# Volatility Month           -1.255851 -1.181668   -1.094022    -1.583215
#
# ...

# %%
std_perf_df = daily_returns_perf_df.std()/3

std_perf_df
# Out:
# basicmaterials            0.928794
#  communicationservices    3.665397
#  consumercyclical         1.663688
#  consumerdefensive        3.476464
#  energy                   0.912969
#  financial                4.399903
#  healthcare               0.781369
#  industrials              9.223759
#  realestate               0.812112
#  technology               0.610947
#  utilities                0.517381
# dtype: float64

# %%
daily_returns_growth_df = growth_stats_df.pct_change().dropna()

daily_returns_growth_df
# Out:
#              basicmaterials   communicationservices   consumercyclical  \
# metrics
# EPS Next Y        -8.454545              -36.088889           6.936508
# EPS Next 5Y       -0.756098               -0.751425          -0.814000
# Sales Q/Q         -1.375000               -0.872611          -0.892473
# EPS Q/Q            0.266667               -3.400000          -2.200000
#
#               consumerdefensive    energy   financial   healthcare  \
# metrics
# EPS Next Y             1.801111 -1.945339    0.070886     0.733333
# EPS Next 5Y           -0.408965 -0.547288   -0.054374    -0.279882
# Sales Q/Q             -0.516779 -2.623762   -0.887500    -0.556286
# EPS Q/Q               -1.416667  4.609756    5.777778     1.296296
#
#               industrials   realestate   technology   utilities
# metrics
# EPS Next Y       2.654348   -14.685714     7.613636    0.278226
# EPS Next 5Y     -0.603411    -0.373695    -0.496922   -0.337539
# ...

# %%
std_growth_df = daily_returns_growth_df.std()/3

std_growth_df
# Out:
# basicmaterials            1.324868
#  communicationservices    5.750123
#  consumercyclical         1.389364
#  consumerdefensive        0.455908
#  energy                   1.091273
#  financial                1.021241
#  healthcare               0.288666
#  industrials              1.201018
#  realestate               2.333591
#  technology               1.326870
#  utilities                0.275281
# dtype: float64

# %%
daily_returns_val_df = val_stats_df.pct_change().dropna()

daily_returns_val_df
# Out:
#              basicmaterials   communicationservices   consumercyclical  \
# metrics
# PEG               -0.835859               -0.817429          -0.877518
# Price/Sales       -0.610256               -0.537797          -0.664474
# Price/Book         0.605263                0.242991           1.254902
# Price/FCF          8.786885               10.000000           8.243478
#
#               consumerdefensive    energy   financial   healthcare  \
# metrics
# PEG                   -0.823206 -0.910753   -0.878021    -0.823002
# Price/Sales           -0.678245 -0.481928    1.174528     0.769585
# Price/Book             0.840909  0.395349   -0.661605    -0.440972
# Price/FCF              9.314815  4.800000   10.500000     7.128882
#
#               industrials   realestate   technology   utilities
# metrics
# PEG             -0.871418    -0.875852    -0.844021   -0.758140
# Price/Sales     -0.578313     0.078431    -0.174074   -0.410256
# ...

# %%
std_val_df = daily_returns_val_df.std()/3

std_val_df
# Out:
# basicmaterials            1.525850
#  communicationservices    1.734918
#  consumercyclical         1.426148
#  consumerdefensive        1.608847
#  energy                   0.874388
#  financial                1.796695
#  healthcare               1.236496
#  industrials              1.493743
#  realestate               4.035828
#  technology               1.387990
#  utilities                1.077554
# dtype: float64

# %%
daily_returns_profit_df = profit_stats_df.pct_change().dropna()

daily_returns_profit_df
# Out:
#                   basicmaterials   communicationservices   consumercyclical  \
# metrics
# Operating Margin        0.845238                2.024390           0.554054
# Gross Margin            1.967742                7.887097           4.704348
# ROE                    -0.778261               -0.949183          -0.731707
# ROA                    -0.480392               -0.607143          -0.579545
#
#                    consumerdefensive    energy   financial   healthcare  \
# metrics
# Operating Margin            0.588235  7.384615    1.962085     1.000000
# Gross Margin                5.296296  6.963303    0.168800    11.400000
# ROE                        -0.764706 -0.974654   -0.875428    -1.643548
# ROA                        -0.537500 -1.090909   -0.879121    -0.248120
#
#                    industrials   realestate   technology   utilities
# metrics
# Operating Margin      0.416667     0.713693     0.850000    0.646018
# ...

# %%
std_profit_df = daily_returns_profit_df.std()/3

std_profit_df
# Out:
# basicmaterials            0.422467
#  communicationservices    1.362485
#  consumercyclical         0.847963
#  consumerdefensive        0.943222
#  energy                   1.580507
#  financial                0.446471
#  healthcare               1.982484
#  industrials              0.613595
#  realestate               0.460177
#  technology               2.008283
#  utilities                0.552476
# dtype: float64

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_profit_df["basicmaterials"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_profit_df["basicmaterials"]

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'F'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_profit_df[" energy"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_profit_df[" energy"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_profit_df[" consumercyclical"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_profit_df[" consumercyclical"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D-'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_profit_df[" consumerdefensive"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_profit_df[" consumerdefensive"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D-'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_profit_df[" energy"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_profit_df[" energy"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_profit_df[" financial"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_profit_df[" financial"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'F'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_profit_df[" healthcare"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_profit_df[" healthcare"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'C-'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_profit_df[" industrials"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_profit_df[" industrials"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'F'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_profit_df[" realestate"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_profit_df[" realestate"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'F'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_profit_df[" technology"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_profit_df[" technology"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'C'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_profit_df[" utilities"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_profit_df[" utilities"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'F'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_val_df["basicmaterials"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_val_df["basicmaterials"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_val_df[" communicationservices"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_val_df[" communicationservices"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'C-'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_val_df[" consumercyclical"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_val_df[" consumercyclical"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_val_df[" consumerdefensive"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_val_df[" consumerdefensive"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_val_df[" energy"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_val_df[" energy"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D-'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_val_df[" financial"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_val_df[" financial"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'C-'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_val_df[" healthcare"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_val_df[" healthcare"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_val_df[" industrials"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_val_df[" industrials"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_val_df[" realestate"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_val_df[" realestate"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'F'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_val_df[" technology"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_val_df[" technology"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_val_df[" utilities"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_val_df[" utilities"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_growth_df["basicmaterials"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_growth_df["basicmaterials"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_growth_df[" communicationservices"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_growth_df[" communicationservices"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_growth_df[" consumercyclical"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_growth_df[" consumercyclical"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_growth_df[" consumerdefensive"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_val_df[" consumerdefensive"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'F'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_growth_df[" energy"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_growth_df[" energy"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_growth_df[" financial"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_growth_df[" financial"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_growth_df[" healthcare"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_growth_df[" healthcare"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'F'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_growth_df[" industrials"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_growth_df[" industrials"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_growth_df[" realestate"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_growth_df[" realestate"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'C+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_growth_df[" technology"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_growth_df[" technology"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_growth_df[" utilities"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_growth_df[" utilities"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'F'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_perf_df["basicmaterials"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_perf_df["basicmaterials"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D-'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_perf_df[" communicationservices"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_perf_df[" communicationservices"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'B+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_perf_df[" consumercyclical"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_perf_df[" consumercyclical"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_perf_df[" consumerdefensive"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_perf_df[" consumerdefensive"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'B+'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_perf_df[" energy"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_perf_df[" energy"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D-'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_perf_df[" financial"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_perf_df[" financial"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'F'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_perf_df[" healthcare"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_perf_df[" healthcare"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D-'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_perf_df[" industrials"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_perf_df[" industrials"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'F'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_perf_df[" realestate"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_perf_df[" realestate"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'D-'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_perf_df[" technology"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_perf_df[" technology"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'F'

# %%
def numeric_to_letter_grade(data):
    
    output = 'F'
    data = std_perf_df[" utilities"]
    
    if data == 4.3:
        output = 'A+'
    elif data >= 4.0:
        data = 'A'
    elif data >= 3.7:
        output = 'A-'
    elif data >= 3.3:
        output = 'B+'
    elif data >= 3:
        output = 'B'
    elif data >= 2.7:
        output = 'B-'
    elif data >= 2.3:
        output = 'C+'
    elif data >= 2:
        output = 'C'
    elif data >= 1.7:
        output = 'C-'
    elif data >= 1.3:
        output = 'D+'
    elif data >= 1:
        output = 'D'
    elif data >= 0.7:
        output = 'D-'

    return output

# %%
data = std_perf_df[" utilities"]
output = "A"

numeric_to_letter_grade(data)
   # return output.apply(numeric_to_letter_grade)
# Out:
# 'F'
